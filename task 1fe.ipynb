# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
data = {
    'Transmission': ['Automatic', 'Manual', 'Automatic', 'Manual'],
    'Color': ['Red', 'Blue', 'Green', 'Red']
}
df = pd.DataFrame(data)
le = LabelEncoder()
df['Transmission_encoded'] = le.fit_transform(df['Transmission'])
df = pd.get_dummies(df, columns=['Color'], drop_first=True)
print(df)
# Out:
#   Transmission  Transmission_encoded  Color_Green  Color_Red
# 0    Automatic                     0        False       True
# 1       Manual                     1        False      False
# 2    Automatic                     0         True      False
# 3       Manual                     1        False       True
